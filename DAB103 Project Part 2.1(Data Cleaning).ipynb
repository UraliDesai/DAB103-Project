# %%
import numpy as np # using for array and linear algebra
import pandas as pd # read csv file
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# First, import all of the packages that are used for data preprocessing, such as numpy and pandas, which are used to eliminate missing values and change data types.

# %% [markdown]
# Using OS tell the system the path to the dataset so it can easily use it.

# %%
import os
for dirname, _, filenames in os.walk('E:\SEM 1\Data Analytics Tools\Project\Dataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# E:\SEM 1\Data Analytics Tools\Project\Dataset\city_day.csv
# E:\SEM 1\Data Analytics Tools\Project\Dataset\city_hour.csv
# E:\SEM 1\Data Analytics Tools\Project\Dataset\stations.csv
# E:\SEM 1\Data Analytics Tools\Project\Dataset\station_day.csv
# E:\SEM 1\Data Analytics Tools\Project\Dataset\station_hour.csv

# %% [markdown]
# Using pandas and .read csv function, read all csv from floder and save it to in new variable.

# %%
#read csv file from floder
city_day     = pd.read_csv("E:\SEM 1\Data Analytics Tools\Project\Dataset\city_day.csv")
city_hour    = pd.read_csv("E:\SEM 1\Data Analytics Tools\Project\Dataset\city_hour.csv")
station_day  = pd.read_csv("E:\SEM 1\Data Analytics Tools\Project\Dataset\station_day.csv")
station_hour = pd.read_csv("E:\SEM 1\Data Analytics Tools\Project\Dataset\station_hour.csv")
stations     = pd.read_csv("E:\SEM 1\Data Analytics Tools\Project\Dataset\stations.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
print("List of Columns in each dataframe : ",'\n')
print("City day : ",list(city_day.columns),'\n')
print("city_hour : ",list(city_hour.columns),'\n')
print("station_day : ",list(station_day.columns),'\n')
print('Station_hour : ',list(station_hour.columns),'\n')
print("Station : ",list(stations.columns),'\n')
# Out:
# List of Columns in each dataframe :
#
# City day :  ['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket']
#
# city_hour :  ['City', 'Datetime', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket']
#
# station_day :  ['StationId', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket']
#
# Station_hour :  ['StationId', 'Datetime', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket']
#
# Station :  ['StationId', 'StationName', 'City', 'State', 'Status']

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Data Cleaning in city_day file

# %%
city_day
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
city_day.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
#get information about datatype of each variable
city_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %% [markdown]
# Because the date's datatype is object, we use pd.to_datetime to convert it to a date time.

# %%
city_day["Date"] = pd.to_datetime(city_day["Date"])

# %%
city_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  datetime64[ns]
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: datetime64[ns](1), float64(13), object(2)
# memory usage: 3.6+ MB

# %% [markdown]
# Get information on the total null values for each column in the city day CSV file using the isnull() method.

# %%
city_day.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
#total values of city_day file
city_day.shape
# Out:
# (29531, 16)

# %% [markdown]
# Using the dropna() function, remove all null values from the file.

# %%
City_day_clean=city_day.dropna()

# %% [markdown]
# Use the to csv() function to create the new city day CSV file without missing value to local memory, with index set to False.

# %%
City_day_clean.to_csv("E:\SEM 1\Data Analytics Tools\Project\Cleaned\City_day.csv",index=False)

# %%
city_day.isnull().sum()
# Out:
# City          0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %%
city_day.shape
# Out:
# (6236, 16)

# %% [markdown]
# ## Data Cleaning in city_hour file

# %%
city_hour
# Out:
#                  City             Datetime  PM2.5   PM10    NO    NO2    NOx  \
# 0           Ahmedabad  2015-01-01 01:00:00    NaN    NaN  1.00  40.01  36.37
# 1           Ahmedabad  2015-01-01 02:00:00    NaN    NaN  0.02  27.75  19.73
# 2           Ahmedabad  2015-01-01 03:00:00    NaN    NaN  0.08  19.32  11.08
# 3           Ahmedabad  2015-01-01 04:00:00    NaN    NaN  0.30  16.45   9.20
# 4           Ahmedabad  2015-01-01 05:00:00    NaN    NaN  0.12  14.90   7.85
# ...               ...                  ...    ...    ...   ...    ...    ...
# 707870  Visakhapatnam  2020-06-30 20:00:00   9.50  36.00  2.75  25.57  15.85
# 707871  Visakhapatnam  2020-06-30 21:00:00  17.25  49.25  3.62  33.20  20.62
# 707872  Visakhapatnam  2020-06-30 22:00:00  36.00  71.00  2.20  30.80  18.20
# 707873  Visakhapatnam  2020-06-30 23:00:00  15.75  63.00  1.02  28.90  16.00
# 707874  Visakhapatnam  2020-07-01 00:00:00  15.00  66.00  0.40  26.85  14.05
#
# ...

# %%
city_hour.head()
# Out:
#         City             Datetime  PM2.5  PM10    NO    NO2    NOx  NH3    CO  \
# 0  Ahmedabad  2015-01-01 01:00:00    NaN   NaN  1.00  40.01  36.37  NaN  1.00
# 1  Ahmedabad  2015-01-01 02:00:00    NaN   NaN  0.02  27.75  19.73  NaN  0.02
# 2  Ahmedabad  2015-01-01 03:00:00    NaN   NaN  0.08  19.32  11.08  NaN  0.08
# 3  Ahmedabad  2015-01-01 04:00:00    NaN   NaN  0.30  16.45   9.20  NaN  0.30
# 4  Ahmedabad  2015-01-01 05:00:00    NaN   NaN  0.12  14.90   7.85  NaN  0.12
#
#       SO2      O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  122.07     NaN      0.0      0.0     0.0  NaN        NaN
# 1   85.90     NaN      0.0      0.0     0.0  NaN        NaN
# 2   52.83     NaN      0.0      0.0     0.0  NaN        NaN
# 3   39.53  153.58      0.0      0.0     0.0  NaN        NaN
# 4   32.63     NaN      0.0      0.0     0.0  NaN        NaN

# %%
##get information datatype of variable
city_hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 707875 entries, 0 to 707874
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   City        707875 non-null  object
#  1   Datetime    707875 non-null  object
#  2   PM2.5       562787 non-null  float64
#  3   PM10        411138 non-null  float64
#  4   NO          591243 non-null  float64
#  5   NO2         590753 non-null  float64
#  6   NOx         584651 non-null  float64
#  7   NH3         435333 non-null  float64
#  8   CO          621358 non-null  float64
#  9   SO2         577502 non-null  float64
#  10  O3          578667 non-null  float64
#  11  Benzene     544229 non-null  float64
#  12  Toluene     487268 non-null  float64
#  13  Xylene      252046 non-null  float64
#  14  AQI         578795 non-null  float64
#  15  AQI_Bucket  578795 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 86.4+ MB

# %%
#convert datatime variable into date datatype
city_hour["Datetime"] = pd.to_datetime(city_hour["Datetime"]).dt.normalize()

# %%
city_hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 707875 entries, 0 to 707874
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   City        707875 non-null  object
#  1   Datetime    707875 non-null  datetime64[ns]
#  2   PM2.5       562787 non-null  float64
#  3   PM10        411138 non-null  float64
#  4   NO          591243 non-null  float64
#  5   NO2         590753 non-null  float64
#  6   NOx         584651 non-null  float64
#  7   NH3         435333 non-null  float64
#  8   CO          621358 non-null  float64
#  9   SO2         577502 non-null  float64
#  10  O3          578667 non-null  float64
#  11  Benzene     544229 non-null  float64
#  12  Toluene     487268 non-null  float64
#  13  Xylene      252046 non-null  float64
#  14  AQI         578795 non-null  float64
#  15  AQI_Bucket  578795 non-null  object
# dtypes: datetime64[ns](1), float64(13), object(2)
# memory usage: 86.4+ MB

# %%
#rename name of datetime variable into date name
city_hour = city_hour.rename(columns={'Datetime': 'Date'})

# %%
#represent the total null values of file
city_hour.isnull().sum()
# Out:
# City               0
# Date               0
# PM2.5         145088
# PM10          296737
# NO            116632
# NO2           117122
# NOx           123224
# NH3           272542
# CO             86517
# SO2           130373
# O3            129208
# Benzene       163646
# Toluene       220607
# Xylene        455829
# AQI           129080
# AQI_Bucket    129080
# dtype: int64

# %%
city_hour.shape
# Out:
# (707875, 16)

# %%
#remove all null values from the csv file
City_hour_clean=city_hour.dropna()

# %%
#make a new csv file without any missing value and store it
City_hour_clean.to_csv("E:\SEM 1\Data Analytics Tools\Project\Cleaned\City_hour.csv",index=False)

# %%
City_hour_clean.isnull().sum()
# Out:
# City          0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %%
City_hour_clean.shape
# Out:
# (129277, 16)

# %%
City_hour_clean.head()
# Out:
#             City       Date   PM2.5    PM10    NO    NO2    NOx   NH3   CO  \
# 50888  Amaravati 2017-11-25  104.00  148.50  1.93  23.00  13.75  9.80  0.1
# 50889  Amaravati 2017-11-25   94.50  142.00  1.33  16.25   9.75  9.65  0.1
# 50890  Amaravati 2017-11-25   82.75  126.50  1.47  14.83   9.07  9.70  0.1
# 50893  Amaravati 2017-11-25   68.50  117.00  1.35  13.60   8.35  7.40  0.1
# 50894  Amaravati 2017-11-25   69.25  112.25  1.52  11.80   7.55  9.25  0.1
#
#          SO2      O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 50888  15.30  117.62     0.30    10.40    0.23  155.0   Moderate
# 50889  17.00  136.23     0.28     7.10    0.15  159.0   Moderate
# 50890  15.40  149.92     0.20     4.55    0.08  173.0   Moderate
# 50893  21.80  161.70     0.10     2.30    0.00  191.0   Moderate
# 50894  21.38  161.68     0.10     2.35    0.00  191.0   Moderate

# %% [markdown]
# ## Data Cleaning in station_day file

# %%
station_day.head()
# Out:
#   StationId        Date  PM2.5    PM10    NO    NO2    NOx    NH3    CO  \
# 0     AP001  2017-11-24  71.36  115.75  1.75  20.65  12.40  12.19  0.10
# 1     AP001  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72  0.12
# 2     AP001  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28  0.14
# 3     AP001  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91  0.11
# 4     AP001  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42  0.09
#
#      SO2      O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 0  10.76  109.26     0.17     5.92    0.10    NaN        NaN
# 1  15.24  127.09     0.20     6.50    0.06  184.0   Moderate
# 2  26.96  117.44     0.22     7.95    0.08  197.0   Moderate
# 3  33.59  111.81     0.29     7.63    0.12  198.0   Moderate
# 4  19.00  138.18     0.17     5.02    0.07  188.0   Moderate

# %%
#get to know that datatype of varibale
station_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108035 entries, 0 to 108034
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   StationId   108035 non-null  object
#  1   Date        108035 non-null  object
#  2   PM2.5       86410 non-null   float64
#  3   PM10        65329 non-null   float64
#  4   NO          90929 non-null   float64
#  5   NO2         91488 non-null   float64
#  6   NOx         92535 non-null   float64
#  7   NH3         59930 non-null   float64
#  8   CO          95037 non-null   float64
#  9   SO2         82831 non-null   float64
#  10  O3          82467 non-null   float64
#  11  Benzene     76580 non-null   float64
#  12  Toluene     69333 non-null   float64
#  13  Xylene      22898 non-null   float64
#  14  AQI         87025 non-null   float64
#  15  AQI_Bucket  87025 non-null   object
# dtypes: float64(13), object(3)
# memory usage: 13.2+ MB

# %%
#convert datatype into date 
station_day["Date"] = pd.to_datetime(station_day["Date"])

# %%
station_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108035 entries, 0 to 108034
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   StationId   108035 non-null  object
#  1   Date        108035 non-null  datetime64[ns]
#  2   PM2.5       86410 non-null   float64
#  3   PM10        65329 non-null   float64
#  4   NO          90929 non-null   float64
#  5   NO2         91488 non-null   float64
#  6   NOx         92535 non-null   float64
#  7   NH3         59930 non-null   float64
#  8   CO          95037 non-null   float64
#  9   SO2         82831 non-null   float64
#  10  O3          82467 non-null   float64
#  11  Benzene     76580 non-null   float64
#  12  Toluene     69333 non-null   float64
#  13  Xylene      22898 non-null   float64
#  14  AQI         87025 non-null   float64
#  15  AQI_Bucket  87025 non-null   object
# dtypes: datetime64[ns](1), float64(13), object(2)
# memory usage: 13.2+ MB

# %%
station_day.isnull().sum()
# Out:
# StationId         0
# Date              0
# PM2.5         21625
# PM10          42706
# NO            17106
# NO2           16547
# NOx           15500
# NH3           48105
# CO            12998
# SO2           25204
# O3            25568
# Benzene       31455
# Toluene       38702
# Xylene        85137
# AQI           21010
# AQI_Bucket    21010
# dtype: int64

# %%
station_day.shape
# Out:
# (108035, 16)

# %%
#eliminate all missing value from CSV file
sation_day_clean=station_day.dropna()

# %%
#create and store it new csv file without index and missing values
sation_day_clean.to_csv("E:\SEM 1\Data Analytics Tools\Project\Cleaned\station_day.csv",index=False)

# %%
sation_day_clean.isnull().sum()
# Out:
# StationId     0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %%
sation_day_clean.shape
# Out:
# (10314, 16)

# %%
#cleaned new csv file
sation_day_clean.head()
# Out:
#   StationId       Date  PM2.5    PM10    NO    NO2    NOx    NH3    CO    SO2  \
# 1     AP001 2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72  0.12  15.24
# 2     AP001 2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28  0.14  26.96
# 3     AP001 2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91  0.11  33.59
# 4     AP001 2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42  0.09  19.00
# 5     AP001 2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25  0.16  10.55
#
#        O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 1  127.09     0.20     6.50    0.06  184.0   Moderate
# 2  117.44     0.22     7.95    0.08  197.0   Moderate
# 3  111.81     0.29     7.63    0.12  198.0   Moderate
# 4  138.18     0.17     5.02    0.07  188.0   Moderate
# 5  109.74     0.21     4.71    0.08  173.0   Moderate

# %% [markdown]
# ## Data Cleaning in station_hour file

# %%
station_hour.head()
# Out:
#   StationId             Datetime  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 0     AP001  2017-11-24 17:00:00  60.50   98.00  2.35  30.80  18.25   8.50
# 1     AP001  2017-11-24 18:00:00  65.50  111.25  2.70  24.20  15.07   9.77
# 2     AP001  2017-11-24 19:00:00  80.00  132.00  2.10  25.18  15.15  12.02
# 3     AP001  2017-11-24 20:00:00  81.50  133.25  1.95  16.25  10.23  11.58
# 4     AP001  2017-11-24 21:00:00  75.25  116.00  1.43  17.48  10.43  12.03
#
#     CO    SO2      O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  0.1  11.85  126.40      0.1     6.10    0.10  NaN        NaN
# 1  0.1  13.17  117.12      0.1     6.25    0.15  NaN        NaN
# 2  0.1  12.08   98.98      0.2     5.98    0.18  NaN        NaN
# 3  0.1  10.47  112.20      0.2     6.72    0.10  NaN        NaN
# 4  0.1   9.12  106.35      0.2     5.75    0.08  NaN        NaN

# %%
#display the datatype of each variable
station_hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2589083 entries, 0 to 2589082
# Data columns (total 16 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   StationId   object
#  1   Datetime    object
#  2   PM2.5       float64
#  3   PM10        float64
#  4   NO          float64
#  5   NO2         float64
#  6   NOx         float64
#  7   NH3         float64
#  8   CO          float64
#  9   SO2         float64
#  10  O3          float64
#  11  Benzene     float64
#  12  Toluene     float64
#  13  Xylene      float64
#  14  AQI         float64
#  15  AQI_Bucket  object
# dtypes: float64(13), object(3)
# memory usage: 316.1+ MB

# %%
#convert object datatype into datetime
station_hour["Datetime"] = pd.to_datetime(station_hour["Datetime"]).dt.normalize()

# %%
station_hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2589083 entries, 0 to 2589082
# Data columns (total 16 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   StationId   object
#  1   Datetime    datetime64[ns]
#  2   PM2.5       float64
#  3   PM10        float64
#  4   NO          float64
#  5   NO2         float64
#  6   NOx         float64
#  7   NH3         float64
#  8   CO          float64
#  9   SO2         float64
#  10  O3          float64
#  11  Benzene     float64
#  12  Toluene     float64
#  13  Xylene      float64
#  14  AQI         float64
#  15  AQI_Bucket  object
# dtypes: datetime64[ns](1), float64(13), object(2)
# memory usage: 316.1+ MB

# %%
#rename column name of datetime into date
station_hour = station_hour.rename(columns={'Datetime': 'Date'})

# %%
station_hour.shape
# Out:
# (2589083, 16)

# %%
#sum of missing values in each varibale of file
station_hour.isnull().sum()
# Out:
# StationId           0
# Date                0
# PM2.5          647689
# PM10          1119252
# NO             553711
# NO2            528973
# NOx            490808
# NH3           1236618
# CO             499302
# SO2            742737
# O3             725973
# Benzene        861579
# Toluene       1042366
# Xylene        2075104
# AQI            570190
# AQI_Bucket     570190
# dtype: int64

# %%
#remove all null values from the file
sation_hour_clean=station_hour.dropna()

# %%
#make and store new csv file into given location
sation_hour_clean.to_csv("E:\SEM 1\Data Analytics Tools\Project\Cleaned\station_hour.csv",index=False)

# %%
sation_hour_clean.head()
# Out:
#    StationId       Date   PM2.5    PM10    NO    NO2    NOx   NH3   CO    SO2  \
# 16     AP001 2017-11-25  104.00  148.50  1.93  23.00  13.75  9.80  0.1  15.30
# 17     AP001 2017-11-25   94.50  142.00  1.33  16.25   9.75  9.65  0.1  17.00
# 18     AP001 2017-11-25   82.75  126.50  1.47  14.83   9.07  9.70  0.1  15.40
# 21     AP001 2017-11-25   68.50  117.00  1.35  13.60   8.35  7.40  0.1  21.80
# 22     AP001 2017-11-25   69.25  112.25  1.52  11.80   7.55  9.25  0.1  21.38
#
#         O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 16  117.62     0.30    10.40    0.23  155.0   Moderate
# 17  136.23     0.28     7.10    0.15  159.0   Moderate
# 18  149.92     0.20     4.55    0.08  173.0   Moderate
# 21  161.70     0.10     2.30    0.00  191.0   Moderate
# 22  161.68     0.10     2.35    0.00  191.0   Moderate

# %%
sation_hour_clean.isnull().sum()
# Out:
# StationId     0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %%
sation_hour_clean.shape
# Out:
# (203693, 16)

# %% [markdown]
# ## Data cleaning in station file

# %%
stations.head()
# Out:
#   StationId                                     StationName  \
# 0     AP001                  Secretariat, Amaravati - APPCB
# 1     AP002  Anand Kala Kshetram, Rajamahendravaram - APPCB
# 2     AP003                      Tirumala, Tirupati - APPCB
# 3     AP004                 PWD Grounds, Vijayawada - APPCB
# 4     AP005          GVM Corporation, Visakhapatnam - APPCB
#
#                 City           State  Status
# 0          Amaravati  Andhra Pradesh  Active
# 1  Rajamahendravaram  Andhra Pradesh     NaN
# 2           Tirupati  Andhra Pradesh     NaN
# 3         Vijayawada  Andhra Pradesh     NaN
# 4      Visakhapatnam  Andhra Pradesh  Active

# %%
stations.shape
# Out:
# (230, 5)

# %% [markdown]
# Sataus has 97 missing values.

# %%
stations.isnull().sum()
# Out:
# StationId       0
# StationName     0
# City            0
# State           0
# Status         97
# dtype: int64

# %%
#remove all missing value from the file
stations_clean=stations.dropna()

# %%
#store new CSV file
stations_clean.to_csv("E:\SEM 1\Data Analytics Tools\Project\Cleaned\stations.csv",index=False)

# %%
stations_clean.shape
# Out:
# (133, 5)

# %%
stations_clean.head()
# Out:
#    StationId                                 StationName           City  \
# 0      AP001              Secretariat, Amaravati - APPCB      Amaravati
# 4      AP005      GVM Corporation, Visakhapatnam - APPCB  Visakhapatnam
# 5      AS001             Railway Colony, Guwahati - APCB       Guwahati
# 10     BR005           DRM Office Danapur, Patna - BSPCB          Patna
# 11     BR006  Govt. High School Shikarpur, Patna - BSPCB          Patna
#
#              State  Status
# 0   Andhra Pradesh  Active
# 4   Andhra Pradesh  Active
# 5            Assam  Active
# 10           Bihar  Active
# 11           Bihar  Active

# %%
stations_clean.isnull().sum()
# Out:
# StationId      0
# StationName    0
# City           0
# State          0
# Status         0
# dtype: int64
